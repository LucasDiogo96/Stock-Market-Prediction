# %%
# Import libs
from yahooquery import Ticker
import pandas as pd
import pandas_ta
from matplotlib import pyplot
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
symbol = "GGBR4.SA"

# Query stock 
stock = Ticker(symbol)

# Get all history data
history = stock.history(period="48mo")

# Let only date as index
history.reset_index(level=["symbol"], inplace=True)

# Reindex data using a DatetimeIndex
history.set_index(pd.DatetimeIndex(history.index), inplace=True)

# %%
# select features that have interest to us
features = ['adjclose','low','high','volume','close']

# Select our features from dataset
data = history[features].copy()

# use technical analyses of the last 21 one days
data.ta.ema(close='adjclose', length=21, append=True)

# fill empty values
data.dropna(inplace=True)

# %%
print(data)

# Plot stock performance data
fig = go.Figure([go.Scatter(x=history.index, y=history['adjclose'])])
fig.show()
# Out:
#              adjclose        low       high    volume      close     EMA_21
# date
# 2018-03-19  12.642447  14.920000  15.450000  10213100  15.030000  13.732243
# 2018-03-20  13.239660  15.020000  15.880000  16580500  15.740000  13.687463
# 2018-03-21  13.441539  15.670000  15.980000  10501000  15.980000  13.665106
# 2018-03-22  12.920026  15.190000  15.950000  15905400  15.360000  13.597372
# 2018-03-23  12.692915  15.000000  15.490000   9854700  15.090000  13.515148
# ...               ...        ...        ...       ...        ...        ...
# 2022-02-14  27.780001  27.459999  28.250000   8495200  27.780001  28.348887
# 2022-02-15  27.670000  27.020000  27.879999   7343800  27.670000  28.287170
# 2022-02-16  27.450001  27.320000  28.090000   9305700  27.450001  28.211064
# 2022-02-17  25.990000  25.959999  27.309999  20896900  25.990000  28.009149
# 2022-02-18  25.690001  25.650000  26.240000   2901600  25.690001  27.798317
#
# [972 rows x 6 columns]
# <div>                            <div id="87eddbc0-72df-423c-a518-71d0c6fd2949" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87eddbc0-72df-423c-a518-71d0c6fd2949")) {                    Plotly.newPlot(                        "87eddbc0-72df-423c-a518-71d0c6fd2949",                        [{"x":["2018-02-19T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-28T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-04T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2018-08-15T00:00:00","2018-08-16T00:00:00","2018-08-17T00:00:00","2018-08-20T00:00:00","2018-08-21T00:00:00","2018-08-22T00:00:00","2018-08-23T00:00:00","2018-08-24T00:00:00","2018-08-27T00:00:00","2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10- ...

# %%
# Features evaluation
X = data[["adjclose"]]
Y = data[['EMA_21']]

# Split data into testing and training sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, train_size = 0.70,)

# Train model
model = LinearRegression().fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
print(f"Features importance:")
# get importance
importance = model.coef_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))

print("--------------------------------------------------------------------------------")
    
# Cross validation
print(f"Cross Validation: {cross_val_score(model, x_train, y_train, scoring='r2', cv=5)}")

print("--------------------------------------------------------------------------------")

print(f"R2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Features importance:
# Feature: 0, Score: 0.96614
# --------------------------------------------------------------------------------
# Cross Validation: [0.97307809 0.97169575 0.98193976 0.96438846 0.97377512]
# --------------------------------------------------------------------------------
# R2 Score: 0.9717465368547161

# %%
df_list = [x_train, x_test, y_train, y_test,y_pred]
df_list = [df.squeeze() for df in df_list]

x_train, x_test, y_train, y_test, y_pred = df_list

# %%
# Plot linear regression result
fig = go.Figure([
    go.Scatter(x=x_train, y=y_train, name='train', mode='markers'),
    go.Scatter(x=x_test,  y=y_test, name='test', mode='markers'),
    go.Scatter(x=x_test,  y=y_pred,  name='prediction')
])

fig.show()
# Out:
# <div>                            <div id="d7f705ab-78f8-49fb-9343-4ca20b971296" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7f705ab-78f8-49fb-9343-4ca20b971296")) {                    Plotly.newPlot(                        "d7f705ab-78f8-49fb-9343-4ca20b971296",                        [{"mode":"markers","name":"train","x":[11.459351539611816,15.806571960449219,12.189291954040527,12.600920677185059,12.920025825500488,12.99280071258545,17.99949073791504,28.393054962158203,11.487068176269531,21.555870056152344,10.412894248962402,26.170000076293945,13.095521926879883,25.122032165527344,10.769674301147461,14.44250202178955,25.492050170898438,15.069748878479004,21.52918243408203,11.679540634155273,10.158064842224121,28.799999237060547,23.530866622924805,29.007938385009766,12.877971649169922,20.21068000793457,26.111968994140625,20.93312644958496,13.320345878601074,27.398393630981445,18.218786239624023,11.627047538757324,30.987590789794922,15.808267593383789,21.698211669921875,13.811607360839844,13.037785530090332,17.820547103881836,11.51331615447998,29.026020050048828,12.093585014343262,10.368958473205566,25.440000534057617,11.971780776977539,28.270000457763672,12.541061401367188,12.837569236755371,21.760488510131836,13.803229331970215,11.592053413391113,14.938779830932617,11.61829948425293,8.42697525024414,17.170291900634766,12.882308006286621,10.940129280090332,27.64253807067871,13.99917221069336,13.543476104736328,25.72318458557129,18.14567756652832,21.008081436157227,14.030340194702148,17.302099227905273,32.507022857666016,11.51331615447998,27.787214279174805,11.469571113586426,10.87465763092041,8.128207206726074,26.684045791625977,13.735939979553223,12.050912857055664,15.34254264831543,11.592053413391113,13.470580101013184,18.192468643188477,11.806471824645996,21.546974182128906,22.890323638916016,10.281086921691895,13.411787986755371,27.904024124145508,18.277484893798828,17.4381046295166,9.604467391967773,19.359102249145508,25.110000610351562,9.595681190490723,24.571739196777344,18.764156341552734,11.76358413696289,29.829999923706055,21.404632568359375,29.15999984741211,13.327682495117188,12.19670581817627,11.180863380432129,24.506982803344727,26.298751831054688,13.757607460021973,25.598054885864258,11.705785751342773,13.650664329528809,29.921215057373047,12.050085067749023,28.280000686645508,13.496006965637207,12.959039688110352,13.419425964355469,13.079361915588379,11.032134056091309,26.79255485534668,13.224641799926758,25.463985443115234,21.395736694335938,12.807022094726562,14.288073539733887,14.024456024169922,26.17767333984375,11.928278923034668,12.871617317199707,17.495420455932617,19.156211853027344,13.547311782836914,14.955718040466309,24.280000686645508,17.59208106994629,10.658937454223633,27.799999237060547,31.015342712402344,23.940093994140625,25.888399124145508,11.64986515045166,28.320716857910156,9.507807731628418,13.456658363342285,14.955601692199707,12.911614418029785,22.151927947998047,23.86125946044922,10.527129173278809,22.258684158325195,28.84250259399414,26.239999771118164,7.592185974121094,32.01000213623047,25.5380802154541,13.675196647644043,14.332006454467773,25.37418556213379,13.732630729675293,27.850000381469727,10.31623363494873,13.804773330688477,25.799999237060547,29.43292808532715,11.058236122131348,11.399580955505371,13.291540145874023,26.308090209960938,13.448060989379883,13.977705955505371,14.911859512329102,12.793710708618164,13.107268333435059,24.85681915283203,12.642446517944336,13.069726943969727,17.442697525024414,25.308813095092773,13.660235404968262,12.058784484863281,14.990805625915527,13.283016204833984,13.6290283203125,18.631052017211914,10.725929260253906,13.308592796325684,13.89686393737793,12.811488151550293,16.79776954650879,12.09358501434326 ...

# %%
fig = px.scatter(
x=x_test,
y=y_pred, 
trendline="rolling", 
trendline_options=dict(window=5),
labels=dict(x='Adjusted Closing Price', y='Prediction'),
title=f"Linear Regression Stock Prediction: {symbol}")

fig.show()
# Out:
# <div>                            <div id="15828744-3b0d-41b3-ac93-9ac185143d20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15828744-3b0d-41b3-ac93-9ac185143d20")) {                    Plotly.newPlot(                        "15828744-3b0d-41b3-ac93-9ac185143d20",                        [{"hovertemplate":"Adjusted Closing Price=%{x}<br>Prediction=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[17.069690704345703,12.989730834960938,13.231247901916504,14.586841583251953,13.115718841552734,11.35583782196045,12.867923736572266,12.224093437194824,14.270499229431152,13.576120376586914,25.11269187927246,13.9190034866333,17.867916107177734,18.04022789001465,13.319085121154785,15.139925956726074,30.656888961791992,18.101741790771484,12.998430252075195,18.797714233398438,25.5889835357666,15.499561309814453,13.520824432373047,14.191412925720215,27.260000228881836,19.859615325927734,32.19420623779297,20.106979370117188,11.397553443908691,17.38997459411621,26.313085556030273,14.103541374206543,25.869155883789062,29.062191009521484,13.602834701538086,15.438161849975586,23.014875411987305,13.298542976379395,13.20628547668457,27.009572982788086,13.310484886169434,10.940129280090332,21.02574920654297,13.129918098449707,30.73733139038086,16.025861740112305,9.31448745727539,12.698493957519531,29.182144165039062,25.215862274169922,10.219574928283691,13.310484886169434,13.521732330322266,16.7539119720459,23.166112899780273,17.911771774291992,11.469571113586426,27.362224578857422,12.076264381408691,23.92667579650879,24.66069984436035,21.449113845825195,13.190106391906738,11.284446716308594,8.593932151794434,13.368271827697754,20.151147842407227,10.228362083435059,15.639909744262695,20.746706008911133,11.643109321594238,11.54546070098877,27.579999923706055,21.351255416870117,18.57842254638672,12.620589256286621,11.423428535461426,13.870523452758789,18.666139602661133,13.155548095703125,13.041932106018066,13.374198913574219,24.790000915527344,12.811771392822266,11.880760192871094,13.70930004119873,27.190000534057617,14.188976287841797,15.694034576416016,12.432901382446289,10.95339584350586,17.92054557800293,11.259601593017578,13.831135749816895,12.432901382446289,8.82240104675293,29.74036979675293,13.862763404846191,12.45655345916748,27.814647674560547,25.990562438964844,15.061349868774414,28.950000762939453,10.861043930053711,11.151022911071777,17.4995059967041,13.828660011291504,17.574504852294922,12.16947078704834,19.98329734802246,10.808320999145508,18.5256290435791,9.938383102416992,11.863265037536621,24.046852111816406,12.580809593200684,14.306096076965332,24.86531639099121,11.802021980285645,12.63790225982666,14.191412925720215,28.528690338134766,29.010000228881836,27.85051155090332,26.652034759521484,13.438216209411621,25.799999237060547,19.479736328125,14.493664741516113,12.61849308013916,22.435583114624023,16.91546058654785,27.65999984741211,11.723284721374512,28.5,12.776400566101074,12.934836387634277,10.588639259338379,31.845626831054688,26.596797943115234,10.193214416503906,23.20170021057129,19.008235931396484,23.72658348083496,13.9190034866333,20.38083839416504,14.332006454467773,12.639801025390625,12.050085067749023,25.399999618530273,25.160625457763672,20.319002151489258,17.2230167388916,28.780000686645508,11.583305358886719,19.68344497680664,18.17203712463379,16.10703468322754,20.67513084411621,13.010193824768066,12.717187881469727,13.07673454284668,13.163656234741211,25.562305450439453,12.311095237731934,12.983743667602539,29.763099670410156,10.752176284790039,28.06999969482422,17.666168212890625,26.313310623168945,12.743882179260254,12.137088775634766,13.462054252624512,13.96080493927002,17 ...
